# %%
import numpy as np
import pandas as pd
import scipy.stats as st

import matplotlib.pyplot as plt

# %% [markdown]
# Данные: Wine Data Set (https://archive.ics.uci.edu/ml/datasets/Wine)

# %%
wine_names = ['Class','Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity','Hue', 'OD280/OD315 of diluted wines', 'Proline']

# %%
wine_names
# Out:
# ['Class',
#  'Alcohol',
#  'Malic acid',
#  'Ash',
#  'Alcalinity of ash',
#  'Magnesium',
#  'Total phenols',
#  'Flavanoids',
#  'Nonflavanoid phenols',
#  'Proanthocyanins',
#  'Color intensity',
#  'Hue',
#  'OD280/OD315 of diluted wines',
#  'Proline']

# %%
wine_data = pd.read_csv("~/data/wine.data", header=None, names=wine_names)
wine_data
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %% [markdown]
# Выборочное среднее:

# %%
wine_data.mean()
# Out:
# Class                             1.938202
# Alcohol                          13.000618
# Malic acid                        2.336348
# Ash                               2.366517
# Alcalinity of ash                19.494944
# Magnesium                        99.741573
# Total phenols                     2.295112
# Flavanoids                        2.029270
# Nonflavanoid phenols              0.361854
# Proanthocyanins                   1.590899
# Color intensity                   5.058090
# Hue                               0.957449
# OD280/OD315 of diluted wines      2.611685
# Proline                         746.893258
# dtype: float64

# %% [markdown]
# Выборочная дисперсия:

# %%
wine_data.var()
# Out:
# Class                               0.600679
# Alcohol                             0.659062
# Malic acid                          1.248015
# Ash                                 0.075265
# Alcalinity of ash                  11.152686
# Magnesium                         203.989335
# Total phenols                       0.391690
# Flavanoids                          0.997719
# Nonflavanoid phenols                0.015489
# Proanthocyanins                     0.327595
# Color intensity                     5.374449
# Hue                                 0.052245
# OD280/OD315 of diluted wines        0.504086
# Proline                         99166.717355
# dtype: float64

# %%
wine_data.quantile(0.25)
# Out:
# Class                             1.0000
# Alcohol                          12.3625
# Malic acid                        1.6025
# Ash                               2.2100
# Alcalinity of ash                17.2000
# Magnesium                        88.0000
# Total phenols                     1.7425
# Flavanoids                        1.2050
# Nonflavanoid phenols              0.2700
# Proanthocyanins                   1.2500
# Color intensity                   3.2200
# Hue                               0.7825
# OD280/OD315 of diluted wines      1.9375
# Proline                         500.5000
# Name: 0.25, dtype: float64

# %%
wine_data.quantile(0.5)
# Out:
# Class                             2.000
# Alcohol                          13.050
# Malic acid                        1.865
# Ash                               2.360
# Alcalinity of ash                19.500
# Magnesium                        98.000
# Total phenols                     2.355
# Flavanoids                        2.135
# Nonflavanoid phenols              0.340
# Proanthocyanins                   1.555
# Color intensity                   4.690
# Hue                               0.965
# OD280/OD315 of diluted wines      2.780
# Proline                         673.500
# Name: 0.5, dtype: float64

# %%
wine_data.quantile(0.75)
# Out:
# Class                             3.0000
# Alcohol                          13.6775
# Malic acid                        3.0825
# Ash                               2.5575
# Alcalinity of ash                21.5000
# Magnesium                       107.0000
# Total phenols                     2.8000
# Flavanoids                        2.8750
# Nonflavanoid phenols              0.4375
# Proanthocyanins                   1.9500
# Color intensity                   6.2000
# Hue                               1.1200
# OD280/OD315 of diluted wines      3.1700
# Proline                         985.0000
# Name: 0.75, dtype: float64

# %% [markdown]
# График(гистограмма) выборочной функции распределения

# %%
plt.hist(wine_data['Alcohol'])
# Out:
# (array([ 1., 10., 19., 31., 21., 27., 25., 25., 17.,  2.]),
#  array([11.03, 11.41, 11.79, 12.17, 12.55, 12.93, 13.31, 13.69, 14.07,
#         14.45, 14.83]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Ядерная оценка плотности вероятности

# %%
wine_data['Alcohol'].plot.kde()

# %%
Доверительные интервалы для матожидания:

# %%
st.norm.interval(alpha=0.9, loc=np.mean(wine_data['Alcohol']), scale=st.sem(wine_data['Alcohol']))
# Out:
# (12.900530325862134, 13.100705629194033)

# %%
st.norm.interval(alpha=0.95, loc=np.mean(wine_data['Alcohol']), scale=st.sem(wine_data['Alcohol']))
# Out:
# (12.881356184655958, 13.119879770400209)
